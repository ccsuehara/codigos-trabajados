# %% [markdown]
# # Manejo de bases de datos para las ciencias sociales III

# %% [markdown]
# ### Juntar datos (merge)
#
# A veces tenemos los datos que nos interesan, esparcidos en diferentes dataframes.
# 1er paso para hacer la unión de datos: Identificar el identificador único!

# %% [markdown]
# La sintaxis más general de un merge es la siguiente:
#
# ``` python
# pd.merge(left = left_df,
#          right=right_df,
#          left_on=colname,
#          right_on=colname,
#          how=merge_type)
#
# ```
#
# El merge_type (o tipo de merge puede ser):
#
# - left: quedan todas las observaciones (por keys) de las mano izquierda
# - right: quedan todas las observaciones (por keys) de la mano derecha
# - outer: es la unión de los keys de ambas bases
# - inner: es la intersección de los keys de ambas bases.

# %%
import pandas as pd

## Leyendo los archivos.

df = pd.read_csv("/content/Datos_abiertos_admision_2021_1_2024_1 (5).csv")
#pbi = pd.read_csv("https://github.com/ccsuehara/python_para_las_ccss/blob/main/Clase%204/data/pbi.csv")

def str_replace(txt):
    return txt.replace("á", "a").replace("é", "e").replace("í", "i").replace(
        "ó", "o").replace("ú", "u").replace("Á", "A").replace('Prov. Const. del Callao', 'Callao')

# %%
pbi = pd.read_csv("/content/pbi.csv")

# %%
df['DOMICILIO_DEPA'] = df['DOMICILIO_DEPA'].str.title()
pbi_long = pbi.melt(id_vars="Anio", var_name = "departamento", value_name = "pbi")

df['DOMICILIO_DEPA'] = df['DOMICILIO_DEPA'].apply(str_replace)
pbi_long['departamento'] = pbi_long['departamento'].apply(str_replace)

pbi_2019 = pbi_long[pbi_long['Anio'] == 2019]

# %%
pbi_long['departamento'].unique()
# Out:
# array(['Amazonas', 'Ancash', 'Apurimac', 'Arequipa', 'Ayacucho',
#        'Cajamarca', 'Cusco', 'Huancavelica', 'Huanuco', 'Ica', 'Junin',
#        'La Libertad', 'Lambayeque', 'Lima', 'Callao', 'Region Lima',
#        'Provincia de Lima', 'Loreto', 'Madre de Dios', 'Moquegua',
#        'Pasco', 'Piura', 'Puno', 'San Martin', 'Tacna', 'Tumbes',
#        'Ucayali'], dtype=object)

# %%
df['DOMICILIO_DEPA'].unique()
# Out:
# array(['Lima', 'Ancash', 'Ayacucho', 'Junin', 'Ica', 'Amazonas', 'Tacna',
#        'Callao', 'Lambayeque', 'San Martin', 'Cajamarca', 'Huanuco',
#        'Huancavelica', 'Ucayali', 'Cusco', 'Arequipa', 'Puno', 'Moquegua',
#        'La Libertad', 'Pasco', 'Apurimac', 'Madre De Dios', 'Piura',
#        'Tumbes', 'Loreto'], dtype=object)

# %%
lst = df['DOMICILIO_DEPA'].unique()

lst.sort()
lst

# %%
pbi_long['departamento'].unique().sort()
lst2 = pbi_long['departamento'].unique()
lst2.sort()
lst2

# %%
pd.merge(df,
         pbi_2019,
         left_on = 'DOMICILIO_DEPA',
         right_on = 'departamento',
         how = 'inner'

)
# Out:
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 1      2DC37F0B9727B6591EC72D7A942647797A200F45D47C9E...
# 2      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# ...                                                  ...
# 42488  370728AB03E7ECDE69265AC64B0A682887B0BA3E40644F...
# 42489  C03C7AC74210DA0F4862BFEDAE45CF3BB5AE9813FCF409...
# 42490  E6337F43BAEF0F59EDF11F6F16A47A908717DE288B7886...
# 42491  13F7CD09C661B02F61218445885DA7C4FDBD87392F7522...
# 42492  89BFAB90B1C8C25D61557264958F988E305385A9351B5C...
#
#                           COLEGIO COLEGIO_DEPA           COLEGIO_PROV  \
# 0           LA DIVINA PROVIDENCIA         LIMA                   LIMA
# 1               86019 LA LIBERTAD       ÁNCASH                 HUARAZ
# 2      0113 DANIEL ALOMIAS ROBLES         LIMA                   LIMA
# 3         SEBASTIAN SALAZAR BONDY         LIMA                   LIMA
# 4               TRILCE LOS OLIVOS         LIMA                   LIMA
# ...                           ...          ...                    ...
# 42488           BARTOLOME HERRERA         LIMA                   LIMA
# 42489             FE Y ALEGRIA 59       CALLAO  PROV CONST DEL CALLAO
# 42490                    CIENCIAS     AYACUCHO               HUAMANGA
# 42491                  SAN CARLOS         LIMA                   LIMA
# 42492             TRILCE SAN JUAN         LIMA                   LIMA
#
#                  COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0                   SURQUILLO         PERÚ                 2020
# 1                      HUARAZ         PERÚ                 2017
# 2      SAN JUAN DE LURIGANCHO         PERÚ                 2016
# 3                 SANTA ANITA         PERÚ                 2018
# 4        SAN MARTÍN DE PORRES         PERÚ                 2020
# ...                       ...          ...                  ...
# 42488              SAN MIGUEL          NaN                 2019
# 42489              VENTANILLA          NaN                 2021
# 42490       SAN JUAN BAUTISTA          NaN                 2022
# 42491              LURIGANCHO          NaN                 2021
# 42492  SAN JUAN DE LURIGANCHO          NaN                 2021
#
#                            ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0                INGENIERÍA DE SISTEMAS          2021              1  ...
# 1      INGENIERÍA DE TELECOMUNICACIONES          2021              1  ...
# 2                   INGENIERÍA MECÁNICA          2021              1  ...
# 3                INGENIERÍA ELECTRÓNICA          2021              1  ...
# 4                          ARQUITECTURA          2021              1  ...
# ...                                 ...           ...            ...  ...
# 42488                  INGENIERÍA CIVIL          2023              1  ...
# 42489                  INGENIERÍA CIVIL          2023              1  ...
# 42490                      ARQUITECTURA          2023              1  ...
# 42491                      ARQUITECTURA          2023              1  ...
# 42492            INGENIERÍA DE SISTEMAS          2023              1  ...
#
#       NACIMIENTO_DEPA        NACIMIENTO_PROV         NACIMIENTO_DIST  \
# 0                LIMA                   LIMA       VILLA EL SALVADOR
# 1              ÁNCASH                 HUARAZ                  HUARAZ
# 2                LIMA                   LIMA             JESÚS MARÍA
# 3                LIMA                   LIMA                    LIMA
# 4                LIMA                   LIMA                   COMAS
# ...               ...                    ...                     ...
# 42488          CALLAO  PROV CONST DEL CALLAO              BELLAVISTA
# 42489          CALLAO  PROV CONST DEL CALLAO                  CALLAO
# 42490        AYACUCHO               HUAMANGA                AYACUCHO
# 42491            LIMA                   LIMA              MIRAFLORES
# 42492            LIMA                   LIMA  SAN JUAN DE LURIGANCHO
#
#             SEXO CALIF_FINAL INGRESO  \
# 0      MASCULINO       3.110      NO
# 1       FEMENINO       3.580      NO
# 2      MASCULINO       8.040      NO
# 3      MASCULINO      10.820      NO
# 4       FEMENINO       6.210      NO
# ...          ...         ...     ...
# 42488  MASCULINO       5.906      NO
# 42489   FEMENINO       2.621      NO
# 42490   FEMENINO       7.974      NO
# 42491   FEMENINO       9.477      NO
# 42492  MASCULINO       7.228      NO
#
#                                                MODALIDAD  Anio departamento  \
# 0      EXTRAORDINARIO1 - DEPORTISTAS CALIFICADOS DE A...  2019         Lima
# 1                                              ORDINARIO  2019       Ancash
# 2                                              ORDINARIO  2019         Lima
# 3                EXTRAORDINARIO2 – INGRESO DIRECTO CEPRE  2019         Lima
# 4                                              ORDINARIO  2019         Lima
# ...                                                  ...   ...          ...
# 42488                                          ORDINARIO  2019       Callao
# 42489                                          ORDINARIO  2019       Callao
# 42490                                          ORDINARIO  2019     Ayacucho
# 42491                                          ORDINARIO  2019         Lima
# 42492                                          ORDINARIO  2019         Lima
#
#              pbi
# 0      240498497
# 1       20059093
# 2      240498497
# 3      240498497
# 4      240498497
# ...          ...
# 42488   22458010
# 42489   22458010
# 42490    5931518
# 42491  240498497
# 42492  240498497
#
# [42493 rows x 25 columns]

# %%
pd.merge(df, pbi_2019,
        left_on = 'DOMICILIO_DEPA',
        right_on = 'departamento'
        #, how = 'left'
        )
